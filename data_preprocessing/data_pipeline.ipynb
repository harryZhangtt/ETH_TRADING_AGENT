# %%
# ETH metrics pipeline (decoupled metrics)
from data_preprocessing.metrics import PipelineConfig, build_universal_metrics

config = PipelineConfig(
    etherscan_api_key="YOUR_KEY",
    debug=False,
)

df = build_universal_metrics(
    period="30d",
    caller="backtest_v2",
    config=config,
    save=True,
)

df
